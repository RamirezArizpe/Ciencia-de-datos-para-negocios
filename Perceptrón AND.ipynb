# %% [markdown]
# <a href="https://colab.research.google.com/github/RamirezArizpe/Ciencia-de-datos-para-negocios/blob/UCA-Inteligencia-Artificial/Perceptr%C3%B3n%20AND.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Realizaremos el modelo del peceptrón para resolver el problema de la operación lógica `AND`

# %% [markdown]
# ## Clase Perceptrón

# %%
class Perceptron:
    def __init__ (self,pesos, sesgo, tasa_de_aprendizaje):


      """
        se documenta la función
        parametros:
           pesos: Es una lista
           sesgo: Es un flotante
           tasa_de_aprendizaje: Es un flotante
      """
      self.pesos = pesos
      self.sesgo = sesgo
      self.tasa_de_aprendizaje = tasa_de_aprendizaje
       # aquí ya acabé de configurar la clase perceptrón
       # comienzo a definir la función de activación
    def funcion_de_activacion(self, z):
        """"
            Parámetros de la función de activación:
            z es el producto de X(pesos+sesgo)
        """
        if z >= 0:
          return 1
        else:
          return 0
        # Fin de la función de activación

        # inicio de la función de entremanient
    def entrenamiento(self, X, Y, epocas):
        """

        """
       # X = [[1,1],[1,0],[0,1],[0,0]]
      # Y = [1,0,0,0]
        for epoca in range(epocas):
          for dato in X:
            # Definimos los datos de la función de entranamiento, que son necesarios para los cálculos
            x1 = dato[0]
            x2 = dato[1]
            y_real = Y[X.index(dato)]
            w1 = self.pesos[0]
            w2 = self.pesos[1]
            b = self.sesgo

            #Hacemos la predicción del modelo
            z = x1*w1 + x2*w2 + b
            y_pred = self.funcion_de_activacion(z)
            # Actualizamos los pesos
            self.pesos[0] = w1 + self.tasa_de_aprendizaje * (y_real - y_pred) * x1
            self.pesos[1] = w2 + self.tasa_de_aprendizaje * (y_real - y_pred) * x2
            self.sesgo = b + self.tasa_de_aprendizaje * (y_real - y_pred)
            print(f"Dato {dato}, Pesos: {self.pesos} y Sesgo: {self.sesgo}")
          print(f"Epoca {epoca}, Pesos: {self.pesos} y Sesgo: {self.sesgo}")
          # fin del entrenamiento

        # inicio de la predicción
        def prediccion(sef, X, Y):
          for dato in X:
            # Definimos los datos de la función de entranamiento, que son necesarios para los cálculos
            x1 = dato[0]
            x2 = dato[1]
            y_real = Y[X.index(dato)]
            w1 = self.pesos[0]
            w2 = self.pesos[1]
            b = self.sesgo
          #Hacemos la predicción del modelo
            z = x1*w1 + x2*w2 + b
            y_pred = self.funcion_de_activacion(z)
            print(f"Dato {dato}, prediccion {y_pred}, valor real {y_real}")

# %% [markdown]
# Definimos los parámetros de entrada

# %%
X = [[1,1],[0,1],[1,0],[0,0]]
Y = [1,0,0,0]
sesgo = 2
pesos = [5,3]
tasa_de_aprendizaje = 0.1

# %% [markdown]
# Inicializamos la clase

# %%
p = Perceptron(pesos, sesgo, tasa_de_aprendizaje)

# %% [markdown]
# Entrenamiento

# %%
epocas = 10
p.entrenamiento(X, Y, epocas)
# Out:
# Dato [1, 1], Pesos: [5.0, 3.0] y Sesgo: 2.0
# Dato [0, 1], Pesos: [5.0, 2.9] y Sesgo: 1.9
# Dato [1, 0], Pesos: [4.9, 2.9] y Sesgo: 1.7999999999999998
# Dato [0, 0], Pesos: [4.9, 2.9] y Sesgo: 1.6999999999999997
# Epoca 0, Pesos: [4.9, 2.9] y Sesgo: 1.6999999999999997
# Dato [1, 1], Pesos: [4.9, 2.9] y Sesgo: 1.6999999999999997
# Dato [0, 1], Pesos: [4.9, 2.8] y Sesgo: 1.5999999999999996
# Dato [1, 0], Pesos: [4.800000000000001, 2.8] y Sesgo: 1.4999999999999996
# Dato [0, 0], Pesos: [4.800000000000001, 2.8] y Sesgo: 1.3999999999999995
# Epoca 1, Pesos: [4.800000000000001, 2.8] y Sesgo: 1.3999999999999995
# Dato [1, 1], Pesos: [4.800000000000001, 2.8] y Sesgo: 1.3999999999999995
# Dato [0, 1], Pesos: [4.800000000000001, 2.6999999999999997] y Sesgo: 1.2999999999999994
# Dato [1, 0], Pesos: [4.700000000000001, 2.6999999999999997] y Sesgo: 1.1999999999999993
# Dato [0, 0], Pesos: [4.700000000000001, 2.6999999999999997] y Sesgo: 1.0999999999999992
# Epoca 2, Pesos: [4.700000000000001, 2.6999999999999997] y Sesgo: 1.0999999999999992
# Dato [1, 1], Pesos: [4.700000000000001, 2.6999999999999997] y Sesgo: 1.0999999999999992
# Dato [0, 1], Pesos: [4.700000000000001, 2.5999999999999996] y Sesgo: 0.9999999999999992
# Dato [1, 0], Pesos: [4.600000000000001, 2.5999999999999996] y Sesgo: 0.8999999999999992
# Dato [0, 0], Pesos: [4.600000000000001, 2.5999999999999996] y Sesgo: 0.7999999999999993
# Epoca 3, Pesos: [4.600000000000001, 2.5999999999999996] y Sesgo: 0.7999999999999993
# Dato [1, 1], Pesos: [4.600000000000001, 2.5999999999999996] y Sesgo: 0.7999999999999993
# Dato [0, 1], Pesos: [4.600000000000001, 2.4999999999999996] y Sesgo: 0.6999999999999993
# Dato [1, 0], Pesos: [4.500000000000002, 2.4999999999999996] y Sesgo: 0.5999999999999993
# Dato [0, 0], Pesos: [4.500000000000002, 2.4999999999999996] y Sesgo: 0.49999999999999933
# Epoca 4, Pesos: [4.500000000000002, 2.4999999999999996] y Sesgo: 0.49999999999999933
# Dato [1, 1], Pesos: [4.500000000000002, 2.4999999999999996] y Sesgo: 0.49999999999999933
# Dato [0, 1], Pesos: [4.500000000000002, 2.3999999999999995] y Sesgo: 0.39999999999999936
# Dato [1, 0], Pesos: [4.400000000000002, 2.3999999999999995] y Sesgo: 0.2999999999999994
# Dato [0, 0], Pesos: [4.400000000000002, 2.3999999999999995] y Sesgo: 0.19999999999999937
# Epoca 5, Pesos: [4.400000000000002, 2.3999999999999995] y Sesgo: 0.19999999999999937
# Dato [1, 1], Pesos: [4.400000000000002, 2.3999999999999995] y Sesgo: 0.19999999999999937
# Dato [0, 1], Pesos: [4.400000000000002, 2.2999999999999994] y Sesgo: 0.09999999999999937
# Dato [1, 0], Pesos: [4.3000000000000025, 2.2999999999999994] y Sesgo: -6.38378239159465e-16
# Dato [0, 0], Pesos: [4.3000000000000025, 2.2999999999999994] y Sesgo: -6.38378239159465e-16
# Epoca 6, Pesos: [4.3000000000000025, 2.2999999999999994] y Sesgo: -6.38378239159465e-16
# Dato [1, 1], Pesos: [4.3000000000000025, 2.2999999999999994] y Sesgo: -6.38378239159465e-16
# Dato [0, 1], Pesos: [4.3000000000000025, 2.1999999999999993] y Sesgo: -0.10000000000000064
# Dato [1, 0], Pesos: [4.200000000000003, 2.1999999999999993] y Sesgo: -0.20000000000000065
# Dato [0, 0], Pesos: [4.200000000000003, 2.1999999999999993] y Sesgo: -0.20000000000000065
# Epoca 7, Pesos: [4.200000000000003, 2.1999999999999993] y Sesgo: -0.20000000000000065
# Dato [1, 1], Pesos: [4.200000000000003, 2.1999999999999993] y Sesgo: -0.20000000000000065
# Dato [0, 1], Pesos: [4.200000000000003, 2.099999999999999] y Sesgo: -0.30000000000000066
# Dato [1, 0], Pesos: [4.100000000000003, 2.099999999999999] y Sesgo: -0.4000000000000007
# Dato [0, 0], Pesos: [4.100000000000003, 2.099999999999999] y Sesgo: -0.4000000000000007
# Epoca 8, Pesos: [4.100000000000003, 2.099999999999999] y Sesgo: -0.4000000000000007
# Dato [1, 1], Pesos: [4.100000000000003, 2.099999999999999] y Sesgo: -0.4000000000000007
# Dato [0, 1], Pesos: [4.100000000000003, 1.9999999999999991] y Sesgo: -0.5000000000000007
# Dato [1, 0], Pesos: [4.0000000000000036, 1.9999999999999991] y Sesgo: -0.6000000000000006
# Dato [0, 0], Pesos: [4.0000000000000036, 1.9999999999999991] y Sesgo: -0.6000000000000006
# Epoca 9, Pesos: [4.0000000000000036, 1.9999999999999991] y Sesgo: -0.6000000000000006

# %% [markdown]
# <a href="https://colab.research.google.com/github/RamirezArizpe/Ciencia-de-datos-para-negocios/blob/UCA-Inteligencia-Artificial/Perceptr%C3%B3n_Ejemplo_NOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Realizaremos el modelo del peceptrón para resolver el problema de la operación lógica `NOT`

# %% [markdown]
# ## Clase Perceptrón

# %%
class Perceptron:
    def __init__ (self,pesos, sesgo, tasa_de_aprendizaje):


      """
        se documenta la función
        parametros:
           pesos: Es una lista
           sesgo: Es un flotante
           tasa_de_aprendizaje: Es un flotante
      """
      self.pesos = pesos
      self.sesgo = sesgo
      self.tasa_de_aprendizaje = tasa_de_aprendizaje
       # aquí ya acabé de configurar la clase perceptrón
       # comienzo a definir la función de activación
    def funcion_de_activacion(self, z):
        """"
            Parámetros de la función de activación:
            z es el producto de X(pesos+sesgo)
        """
        if z >= 0:
          return 1
        else:
          return 0
        # Fin de la función de activación

        # inicio de la función de entremanient
    def entrenamiento(self, X, Y, epocas):
        """

        """
        for epoca in range(epocas):
          for dato in X:
            # Definimos los datos de la función de entranamiento, que son necesarios para los cálculos
            x = dato[0]
            y_real = Y[X.index(dato)]
            w = self.pesos[0]
            b = self.sesgo

            #Hacemos la predicción del modelo
            z = x*w + b
            y_pred = self.funcion_de_activacion(z)
            # Actualizamos los pesos
            self.pesos[0] = w + self.tasa_de_aprendizaje * (y_real - y_pred) * x
            self.sesgo = b + self.tasa_de_aprendizaje * (y_real - y_pred)
            print(f"Dato {dato}, Pesos: {self.pesos} y Sesgo: {self.sesgo}")
          print(f"Epoca {epoca}, Pesos: {self.pesos} y Sesgo: {self.sesgo}")
          # fin del entrenamiento

        # inicio de la predicción
        def prediccion(sef, X, Y):
          for dato in X:
            # Definimos los datos de la función de entranamiento, que son necesarios para los cálculos
            x = dato[0]
            y_real = Y[X.index(dato)]
            w = self.pesos[0]
            b = self.sesgo
          #Hacemos la predicción del modelo
            z = x*w + b
            y_pred = self.funcion_de_activacion(z)
            print(f"Dato {dato}, prediccion {y_pred}, valor real {y_real}")

# %% [markdown]
# Definimos los parámetros de entrada

# %%
X = [[1],[0]]
Y = [0,1]
sesgo = 2
pesos = [5,3]
tasa_de_aprendizaje = 0.1

# %% [markdown]
# Inicializamos la clase

# %%
p = Perceptron(pesos, sesgo, tasa_de_aprendizaje)

# %% [markdown]
# Entrenamiento

# %%
epocas = 100
p.entrenamiento(X, Y, epocas)
# Out:
# Dato [1], Pesos: [3.9000000000000035, 3] y Sesgo: 0.8999999999999992
# Dato [0], Pesos: [3.9000000000000035, 3] y Sesgo: 0.8999999999999992
# Epoca 0, Pesos: [3.9000000000000035, 3] y Sesgo: 0.8999999999999992
# Dato [1], Pesos: [3.8000000000000034, 3] y Sesgo: 0.7999999999999993
# Dato [0], Pesos: [3.8000000000000034, 3] y Sesgo: 0.7999999999999993
# Epoca 1, Pesos: [3.8000000000000034, 3] y Sesgo: 0.7999999999999993
# Dato [1], Pesos: [3.7000000000000033, 3] y Sesgo: 0.6999999999999993
# Dato [0], Pesos: [3.7000000000000033, 3] y Sesgo: 0.6999999999999993
# Epoca 2, Pesos: [3.7000000000000033, 3] y Sesgo: 0.6999999999999993
# Dato [1], Pesos: [3.600000000000003, 3] y Sesgo: 0.5999999999999993
# Dato [0], Pesos: [3.600000000000003, 3] y Sesgo: 0.5999999999999993
# Epoca 3, Pesos: [3.600000000000003, 3] y Sesgo: 0.5999999999999993
# Dato [1], Pesos: [3.500000000000003, 3] y Sesgo: 0.49999999999999933
# Dato [0], Pesos: [3.500000000000003, 3] y Sesgo: 0.49999999999999933
# Epoca 4, Pesos: [3.500000000000003, 3] y Sesgo: 0.49999999999999933
# Dato [1], Pesos: [3.400000000000003, 3] y Sesgo: 0.39999999999999936
# Dato [0], Pesos: [3.400000000000003, 3] y Sesgo: 0.39999999999999936
# Epoca 5, Pesos: [3.400000000000003, 3] y Sesgo: 0.39999999999999936
# Dato [1], Pesos: [3.300000000000003, 3] y Sesgo: 0.2999999999999994
# Dato [0], Pesos: [3.300000000000003, 3] y Sesgo: 0.2999999999999994
# Epoca 6, Pesos: [3.300000000000003, 3] y Sesgo: 0.2999999999999994
# Dato [1], Pesos: [3.200000000000003, 3] y Sesgo: 0.19999999999999937
# Dato [0], Pesos: [3.200000000000003, 3] y Sesgo: 0.19999999999999937
# Epoca 7, Pesos: [3.200000000000003, 3] y Sesgo: 0.19999999999999937
# Dato [1], Pesos: [3.1000000000000028, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [3.1000000000000028, 3] y Sesgo: 0.09999999999999937
# Epoca 8, Pesos: [3.1000000000000028, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [3.0000000000000027, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [3.0000000000000027, 3] y Sesgo: 0.09999999999999937
# Epoca 9, Pesos: [3.0000000000000027, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [2.9000000000000026, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [2.9000000000000026, 3] y Sesgo: 0.09999999999999937
# Epoca 10, Pesos: [2.9000000000000026, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [2.8000000000000025, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [2.8000000000000025, 3] y Sesgo: 0.09999999999999937
# Epoca 11, Pesos: [2.8000000000000025, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [2.7000000000000024, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [2.7000000000000024, 3] y Sesgo: 0.09999999999999937
# Epoca 12, Pesos: [2.7000000000000024, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [2.6000000000000023, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [2.6000000000000023, 3] y Sesgo: 0.09999999999999937
# Epoca 13, Pesos: [2.6000000000000023, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [2.500000000000002, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [2.500000000000002, 3] y Sesgo: 0.09999999999999937
# Epoca 14, Pesos: [2.500000000000002, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [2.400000000000002, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [2.400000000000002, 3] y Sesgo: 0.09999999999999937
# Epoca 15, Pesos: [2.400000000000002, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [2.300000000000002, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [2.300000000000002, 3] y Sesgo: 0.09999999999999937
# Epoca 16, Pesos: [2.300000000000002, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [2.200000000000002, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [2.200000000000002, 3] y Sesgo: 0.09999999999999937
# Epoca 17, Pesos: [2.200000000000002, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [2.100000000000002, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [2.100000000000002, 3] y Sesgo: 0.09999999999999937
# Epoca 18, Pesos: [2.100000000000002, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [2.0000000000000018, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [2.0000000000000018, 3] y Sesgo: 0.09999999999999937
# Epoca 19, Pesos: [2.0000000000000018, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [1.9000000000000017, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [1.9000000000000017, 3] y Sesgo: 0.09999999999999937
# Epoca 20, Pesos: [1.9000000000000017, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [1.8000000000000016, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [1.8000000000000016, 3] y Sesgo: 0.09999999999999937
# Epoca 21, Pesos: [1.8000000000000016, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [1.7000000000000015, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [1.7000000000000015, 3] y Sesgo: 0.09999999999999937
# Epoca 22, Pesos: [1.7000000000000015, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [1.6000000000000014, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [1.6000000000000014, 3] y Sesgo: 0.09999999999999937
# Epoca 23, Pesos: [1.6000000000000014, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [1.5000000000000013, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [1.5000000000000013, 3] y Sesgo: 0.09999999999999937
# Epoca 24, Pesos: [1.5000000000000013, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [1.4000000000000012, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [1.4000000000000012, 3] y Sesgo: 0.09999999999999937
# Epoca 25, Pesos: [1.4000000000000012, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [1.3000000000000012, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [1.3000000000000012, 3] y Sesgo: 0.09999999999999937
# Epoca 26, Pesos: [1.3000000000000012, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [1.200000000000001, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [1.200000000000001, 3] y Sesgo: 0.09999999999999937
# Epoca 27, Pesos: [1.200000000000001, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [1.100000000000001, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [1.100000000000001, 3] y Sesgo: 0.09999999999999937
# Epoca 28, Pesos: [1.100000000000001, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [1.0000000000000009, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [1.0000000000000009, 3] y Sesgo: 0.09999999999999937
# Epoca 29, Pesos: [1.0000000000000009, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [0.9000000000000009, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [0.9000000000000009, 3] y Sesgo: 0.09999999999999937
# Epoca 30, Pesos: [0.9000000000000009, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [0.8000000000000009, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [0.8000000000000009, 3] y Sesgo: 0.09999999999999937
# Epoca 31, Pesos: [0.8000000000000009, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [0.700000000000001, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [0.700000000000001, 3] y Sesgo: 0.09999999999999937
# Epoca 32, Pesos: [0.700000000000001, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [0.600000000000001, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [0.600000000000001, 3] y Sesgo: 0.09999999999999937
# Epoca 33, Pesos: [0.600000000000001, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [0.500000000000001, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [0.500000000000001, 3] y Sesgo: 0.09999999999999937
# Epoca 34, Pesos: [0.500000000000001, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [0.400000000000001, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [0.400000000000001, 3] y Sesgo: 0.09999999999999937
# Epoca 35, Pesos: [0.400000000000001, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [0.30000000000000104, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [0.30000000000000104, 3] y Sesgo: 0.09999999999999937
# Epoca 36, Pesos: [0.30000000000000104, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [0.20000000000000104, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [0.20000000000000104, 3] y Sesgo: 0.09999999999999937
# Epoca 37, Pesos: [0.20000000000000104, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [0.10000000000000103, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [0.10000000000000103, 3] y Sesgo: 0.09999999999999937
# Epoca 38, Pesos: [0.10000000000000103, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [1.0269562977782698e-15, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [1.0269562977782698e-15, 3] y Sesgo: 0.09999999999999937
# Epoca 39, Pesos: [1.0269562977782698e-15, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.09999999999999898, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [-0.09999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 40, Pesos: [-0.09999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: -6.38378239159465e-16
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 41, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 42, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 43, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 44, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 45, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 46, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 47, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 48, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 49, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 50, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 51, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 52, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 53, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 54, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 55, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 56, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 57, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 58, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 59, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 60, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 61, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 62, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 63, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 64, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 65, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 66, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 67, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 68, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 69, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 70, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 71, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 72, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 73, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 74, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 75, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 76, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 77, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 78, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 79, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 80, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 81, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 82, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 83, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 84, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 85, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 86, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 87, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 88, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 89, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 90, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 91, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 92, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 93, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 94, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 95, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 96, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 97, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 98, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [1], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Dato [0], Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937
# Epoca 99, Pesos: [-0.19999999999999898, 3] y Sesgo: 0.09999999999999937

# %% [markdown]
# <a href="https://colab.research.google.com/github/RamirezArizpe/Ciencia-de-datos-para-negocios/blob/Bases-de-datos-No-SQL/archivosJSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ARCHIVOS EN FORMATO JSON**
#
#
# Significado: JSON = JavaScript Object Notation
#
# Uso principal: intercambio de datos entre aplicaciones web, APIs y sistemas distribuidos.
#
# Ventajas:

# %% [markdown]
# EJEMPLO DE UN ARCHIVO EN JSON
#
#
# ```
#
# {
#   "nombre": "Eréndira",
#   "materia": "base de datos NSQL",
#   "alumnos": [
#     {"nombre": "Ana", "edad": 20},
#     {"nombre": "Nayeli", "edad": 20}
#   ]
# }
#
# ```

# %% [markdown]
# Ejericicio 1.
#
#
# 1.   Completa la base de datos con los integrantes de tu problema prototípico, incluye los datos
# calificación del examen, matricula, correo electrónico.
#
# 2.   identifica que tipo de datos contiene tu archivo(string, int..)

# %% [markdown]
# COMO TRABAJAR ARCHIVOS JSON EN PYTHON?
#
# Python tiene un módulo llamado `json` que permite convertir entre objetos de Python y JSON.
#
# Funciones Principales
#
#
# *   convertir un objeto python a cadena JSON
# *   guardar en archivo JSON
# *   leer desde JSON
# *   ...
